# %%
import pandas as pd

# Load the dataset
file_path = 'DataMiningLab1.csv'
df = pd.read_csv(file_path)
df
# Out:
#     Empid              Name Designation  Salary  Experience  Vaccinated
# 0       1        John Smith      Labour   14800            5         no
# 1       2      Emma Johnson       Clerk   25800            2        yes
# 2       3        John Smith     Manager  108000            7         no
# 3       4      Olivia Jones  Supervisor   79000            8        yes
# 4       5        John Smith       Clerk   28000           10         no
# 5       6        Ava Miller     Manager  117000            8        yes
# 6       7        John Smith       Clerk   19700           12         no
# 7       8      Sophia Moore     Manager  252000            2        yes
# 8       9      Lucas Taylor      Labour   15700            5         no
# 9      10        John Smith      Labour   24500           10         no
# 10     11      Mason Thomas  Supervisor   36000           11         no
# 11     12       Mia Jackson     Manager  109000            7        yes
# ...

# %%
# Dimensions
dimensions = df.shape

# Structure
structure = df.info()

# Attribute Names
attribute_names = df.columns.tolist()

# Attribute Values
attribute_values = df.head()

dimensions, structure, attribute_names, attribute_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Empid        25 non-null     int64
#  1   Name         25 non-null     object
#  2   Designation  25 non-null     object
#  3   Salary       25 non-null     int64
#  4   Experience   25 non-null     int64
#  5   Vaccinated   25 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 1.3+ KB
# ((25, 6),
#  None,
#  ['Empid', 'Name', 'Designation', 'Salary', 'Experience ', 'Vaccinated'],
#     Empid          Name Designation  Salary  Experience  Vaccinated
#  0      1    John Smith      Labour   14800            5         no
#  1      2  Emma Johnson       Clerk   25800            2        yes
#  2      3    John Smith     Manager  108000            7         no
#  3      4  Olivia Jones  Supervisor   79000            8        yes
# ...

# %%
first_5_records = df.head()
first_5_records
# Out:
#    Empid          Name Designation  Salary  Experience  Vaccinated
# 0      1    John Smith      Labour   14800            5         no
# 1      2  Emma Johnson       Clerk   25800            2        yes
# 2      3    John Smith     Manager  108000            7         no
# 3      4  Olivia Jones  Supervisor   79000            8        yes
# 4      5    John Smith       Clerk   28000           10         no

# %%
last_5_records = df.tail()
last_5_records
# Out:
#     Empid              Name Designation  Salary  Experience  Vaccinated
# 20     21  Daniel Rodriguez      Labour   12900            5         no
# 21     22        John Smith       Clerk   20400           11        yes
# 22     23         Henry Lee     Manager   96000           12         no
# 23     24      Emily Walker     Manager  106600            4        yes
# 24     25        John Smith      Labour   17000           12        yes

# %%
first_10_records = df.loc[:9, ['Name', 'Designation', 'Salary']]
first_10_records
# Out:
#            Name Designation  Salary
# 0    John Smith      Labour   14800
# 1  Emma Johnson       Clerk   25800
# 2    John Smith     Manager  108000
# 3  Olivia Jones  Supervisor   79000
# 4    John Smith       Clerk   28000
# 5    Ava Miller     Manager  117000
# 6    John Smith       Clerk   19700
# 7  Sophia Moore     Manager  252000
# 8  Lucas Taylor      Labour   15700
# 9    John Smith      Labour   24500

# %%
names_all_records = df['Name']
names_all_records
# Out:
# 0           John Smith
# 1         Emma Johnson
# 2           John Smith
# 3         Olivia Jones
# 4           John Smith
# 5           Ava Miller
# 6           John Smith
# 7         Sophia Moore
# 8         Lucas Taylor
# 9           John Smith
# 10        Mason Thomas
# 11         Mia Jackson
# 12          John Smith
# 13    Charlotte Harris
# 14          John Smith
# 15     Amelia Thompson
# 16          John Smith
# 17     Harper Martinez
# 18    Michael Robinson
# 19          John Smith
# 20    Daniel Rodriguez
# 21          John Smith
# 22           Henry Lee
# 23        Emily Walker
# 24          John Smith
# Name: Name, dtype: object

# %%
all_records = df
all_records
# Out:
#     Empid              Name Designation  Salary  Experience  Vaccinated
# 0       1        John Smith      Labour   14800            5         no
# 1       2      Emma Johnson       Clerk   25800            2        yes
# 2       3        John Smith     Manager  108000            7         no
# 3       4      Olivia Jones  Supervisor   79000            8        yes
# 4       5        John Smith       Clerk   28000           10         no
# 5       6        Ava Miller     Manager  117000            8        yes
# 6       7        John Smith       Clerk   19700           12         no
# 7       8      Sophia Moore     Manager  252000            2        yes
# 8       9      Lucas Taylor      Labour   15700            5         no
# 9      10        John Smith      Labour   24500           10         no
# 10     11      Mason Thomas  Supervisor   36000           11         no
# 11     12       Mia Jackson     Manager  109000            7        yes
# ...

# %%
import numpy as np
from scipy import stats

# %%
# Calculate mean, median, and mode for numeric columns only
numeric_columns = df.select_dtypes(include=[np.number]).columns

mean_values = df[numeric_columns].mean()
median_values = df[numeric_columns].median()
mode_values = df[numeric_columns].mode().iloc[0]

mean_values, median_values, mode_values
# Out:
# (Empid            13.00
#  Salary        65124.00
#  Experience        6.96
#  dtype: float64,
#  Empid            13.0
#  Salary        28000.0
#  Experience        7.0
#  dtype: float64,
#  Empid             1.0
#  Salary        12900.0
#  Experience        5.0
#  Name: 0, dtype: float64)

# %%
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
df.columns = df.columns.str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces with a single space
df.columns = df.columns.str.replace(r'\W+', '', regex=True)
variance_values = df[numeric_columns].var()
covariance_values = df[numeric_columns].cov()

variance_values, covariance_values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-5178e69cd7ab> in <cell line: 4>()
#       2 df.columns = df.columns.str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces with a single space
#       3 df.columns = df.columns.str.replace(r'\W+', '', regex=True)
# ----> 4 variance_values = df[numeric_columns].var()
#       5 covariance_values = df[numeric_columns].cov()
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3897             if is_iterator(key):
#    3898                 key = list(key)
# -> 3899             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3900
#    3901         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
df.columns = df.columns.str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces with a single space
df.columns = df.columns.str.replace(r'\W+', '', regex=True)
correlation_salary_experience = df['Salary'].corr(df['Experience'])
correlation_salary_experience
# Out:
# -0.44321204748133997

# %%
import matplotlib.pyplot as plt

designation_counts = df['Designation'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(designation_counts, labels=designation_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Designation')
plt.show()

# %%
  plt.figure(figsize=(10, 6))
  plt.hist(df['Salary'], bins=10, edgecolor='black')
  plt.title('Histogram of Salary')
  plt.xlabel('Salary')
  plt.ylabel('Frequency')
  plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Salary'], df['Experience'])
plt.title('Scatter Plot of Salary to Experience')
plt.xlabel('Salary')
plt.ylabel('Experience')
plt.show()
